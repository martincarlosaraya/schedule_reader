# %%
from schedule_reader import compdat2df

# %%
ff18_compdat = compdat2df(r'\\statoil.net\unix_st\project\HDsim\ressim\2023a\eclipse\model\FF18_2023A.DATA', verbose=True)
# Out:
# reading file: //statoil.net/unix_st/project/HDsim/ressim/2023a/eclipse/model/FF18_2023A.DATA
# found PATHS keyword:
#  INCLRSPC:../include/runspec
#    INCLGRD:../include/grid
#    INCLEDIT:../include/edit
#    INCPROPS:../include/props
#    INCLREG:../include/regions
#    INCLSOL:../include/solution
#    INCLSUM:../include/summary
#    INCLSCH:../include/schedule
#    INCLHM:../include/hm

# %%
ff18_compdat.dtypes
# Out:
# date                          datetime64[ns]
# well                                category
# I                                      int32
# J                                      int32
# K_up                                   int32
# K_low                                  int32
# status                              category
# saturation table                      object
# transimissibility factor             float64
# well bore diameter                   float64
# Kh                                   float64
# skin                                 float64
# D-factor                             float64
# direction                           category
# pressure equivalent radius           float64
# dtype: object

# %%
ff18_compdat
# Out:
#             date      well   I   J  K_up  K_low status saturation table  \
# 4     2023-05-10  TAWI-NN1  72  56    35     35   OPEN             None
# 5     2023-05-10  TAWI-NN1  72  56    36     36   OPEN             None
# 6     2023-05-10  TAWI-NN1  72  55    36     36   OPEN             None
# 7     2023-05-10  TAWI-NN1  72  55    37     37   OPEN             None
# 8     2023-05-10  TAWI-NN1  72  55    38     38   OPEN             None
# ...          ...       ...  ..  ..   ...    ...    ...              ...
# 12993 2022-09-30  A_32_AT3  59  86    58     58   SHUT             None
# 12994 2022-09-30  A_32_AT3  59  85    58     58   SHUT             None
# 12995 2022-09-30  A_32_AT3  59  85    59     59   SHUT             None
# 12996 2022-09-30  A_32_AT3  59  85    60     60   SHUT             None
# 12997 2022-09-30  A_32_AT3  59  85    61     61   SHUT             None
#
#        transimissibility factor  well bore diameter          Kh  skin  \
# ...
